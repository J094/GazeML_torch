# %% [markdown]
# # Model_based gaze estimation

# %%
import torch
import numpy as np
import os
import json

from src.datasources.unityeyes import UnityEyesDataset
import src.models.gaze_modelbased as GM
import src.utils.gaze as gaze_util

# %%
elg_model = torch.load('./models/v0.2/model-v0.2-(36, 60)-epoch-89-loss-0.7151.pth')
elg_model.eval()
# Out:
# ELG(
#   (convPre): Conv(
#     (conv): Conv2d(1, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (batchNorm2d): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (residualBlockPre1): ResidualBlock(
#     (convLow1): Conv(
#       (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (convLow2): Conv(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (convLow3): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#       (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (convUp): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#       (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (residualBlockPre2): ResidualBlock(
#     (convLow1): Conv(
#       (conv): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       (batchNorm2d): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (convLow2): Conv(
#       (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (convLow3): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#       (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (convUp): Conv(
#       (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (batchNorm2d): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (hourglassBlock): ModuleDict(
#     (0): HourglassBlock(
#       (residualBlock): ModuleDict(
#         (4): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#         (3): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#         (2): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#         (1): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (2): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): HourglassBlock(
#       (residualBlock): ModuleDict(
#         (4): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#         (3): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#         (2): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#         (1): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (2): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): HourglassBlock(
#       (residualBlock): ModuleDict(
#         (4): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#         (3): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#         (2): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#         (1): ModuleDict(
#           (up): ModuleDict(
#             (0): ResidualBlock(
#               (convLow1): Conv(
#                 (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow2): Conv(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convLow3): Conv(
#                 (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (convUp): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (low): ModuleDict(
#             (1): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (2): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (3): ModuleDict(
#               (0): ResidualBlock(
#                 (convLow1): Conv(
#                   (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow2): Conv(
#                   (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convLow3): Conv(
#                   (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (convUp): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (hourglassAfter): ModuleDict(
#     (0): HourglassAfter(
#       (residualBlock): ModuleDict(
#         (0): ResidualBlock(
#           (convLow1): Conv(
#             (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#             (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (convLow2): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (convLow3): Conv(
#             (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#             (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (convUp): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#             (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (convF): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (convH): Conv(
#         (conv): Conv2d(32, 18, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (convM1): Conv(
#         (conv): Conv2d(18, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (convM2): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): HourglassAfter(
#       (residualBlock): ModuleDict(
#         (0): ResidualBlock(
#           (convLow1): Conv(
#             (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#             (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (convLow2): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (convLow3): Conv(
#             (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#             (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (convUp): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#             (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (convF): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (convH): Conv(
#         (conv): Conv2d(32, 18, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (convM1): Conv(
#         (conv): Conv2d(18, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (convM2): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): HourglassAfter(
#       (residualBlock): ModuleDict(
#         (0): ResidualBlock(
#           (convLow1): Conv(
#             (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#             (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (convLow2): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (convLow3): Conv(
#             (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#             (batchNorm2d): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (convUp): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#             (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (convF): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (convH): Conv(
#         (conv): Conv2d(32, 18, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (convM1): Conv(
#         (conv): Conv2d(18, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (convM2): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchNorm2d): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (calLandmarks): CalLandmarks()
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linearRadiusBefore): Linear(
#     (linear): Linear(in_features=36, out_features=100, bias=True)
#     (batchNorm1d): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (linearRadius): ModuleDict(
#     (0): Linear(
#       (linear): Linear(in_features=100, out_features=100, bias=True)
#       (batchNorm1d): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Linear(
#       (linear): Linear(in_features=100, out_features=100, bias=True)
#       (batchNorm1d): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Linear(
#       (linear): Linear(in_features=100, out_features=100, bias=True)
#       (batchNorm1d): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (linearRadiusAfter): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
val_root = "E:/Datasets/UnityEyes_Windows/800x600/val"
val_dataset = UnityEyesDataset(val_root, eye_image_shape=(36, 60), generate_heatmaps=True, random_difficulty=False)

# %%
import torch.utils.data as D
val_dataloader = D.DataLoader(val_dataset, batch_size=1)

# %%
file_stem = val_dataset.file_stems[1]
json_path = os.path.join(val_root, f'{file_stem}.json')
with open(json_path, 'r') as f:
    json_data = json.load(f)
look_vec = np.array(eval(json_data['eye_details']['look_vec']))[:3]

print("look_vec:", look_vec)

# Change the direction of x-axis to convenient the calculation of (pitch, yaw)
# In image coordinate system
look_vec[0] = -look_vec[0]
gaze = gaze_util.vector_to_pitchyaw(look_vec.reshape((1, 3))).flatten()
# Rotate coord system respect to x-axis
if gaze[1] > 0.0:
    gaze[1] = np.pi - gaze[1]
elif gaze[1] < 0.0:
    gaze[1] = -(np.pi + gaze[1])
gaze = gaze.astype(np.float32)
print("gaze:", gaze)
# Out:
# look_vec: [-0.6073  0.2457 -0.7555]
# gaze: [0.24824658 0.6770771 ]

# %%
entry = next(val_dataset.entry_generator())
# Out:
# look_vec: [-0.6073  0.2457 -0.7555]
# gaze: [0.24824658 0.67707712]

# %%
entry = next(iter(val_dataloader))
# Out:
# [-0.4474  0.3418 -0.8264]
# [ 0.34884414 -0.49620443]

# %%
eye_input = entry['eye'].cuda()

# %%
heatmaps_label = entry['heatmaps'].cuda()
landmarks_label = entry['landmarks'].cuda()
radius_label = entry['radius'].cuda()
gaze_label = entry['gaze'].cuda()

# %%
heatmaps_predict, ldmks_predict, radius_predict = elg_model(eye_input)

# %%
ldmks_predict - landmarks_label
# Out:
# tensor([[[-0.0385,  0.0567],
#          [ 0.1204, -0.4359],
#          [-0.8040, -0.0328],
#          [-0.1560, -0.3720],
#          [ 0.2353, -0.0252],
#          [-0.0995, -0.2216],
#          [-0.4782,  0.1631],
#          [-0.5874,  0.0181],
#          [-0.0424, -0.4859],
#          [ 0.2518, -0.3518],
#          [ 0.2509, -0.1021],
#          [ 0.2502,  0.0216],
#          [ 0.0250,  0.2360],
#          [ 0.0209,  0.2355],
#          [-0.1944,  0.1314],
#          [-0.1389, -0.2617],
#          [-0.2212, -0.1346],
#          [-0.4763,  0.1384]]], device='cuda:0', grad_fn=<SubBackward0>)

# %%
ldmks = ldmks_predict.cpu().detach().numpy()

# %%
iris_ldmks = np.array(ldmks[0][0:8])

# %%
iris_ldmks
# Out:
# array([[13.23596  , 20.954514 ],
#        [14.5897255, 12.914356 ],
#        [26.481472 ,  8.350813 ],
#        [40.672108 , 14.19507  ],
#        [47.656075 , 20.519577 ],
#        [40.492092 , 24.457382 ],
#        [26.573088 , 27.282785 ],
#        [16.16451  , 24.81226  ]], dtype=float32)

# %%
iris_center = np.array(ldmks[0][-2])

# %%
iris_center
# Out:
# array([23.062601, 13.701266], dtype=float32)

# %%
eyeball_center = np.array(ldmks[0][-1])

# %%
eyeball_center
# Out:
# array([32.609627, 17.941515], dtype=float32)

# %%
eyeball_radius = radius_predict.cpu().detach().numpy()[0]

# %%
radius_predict - torch.unsqueeze(radius_label, dim=0)
# Out:
# tensor([[-0.3562]], device='cuda:0', grad_fn=<SubBackward0>)

# %%
gaze_predict = GM.estimate_gaze_from_landmarks(iris_ldmks, iris_center, eyeball_center, eyeball_radius)
predict = gaze_predict.reshape(1, 2)
predict
# Out:
# E:\Devoloper\3_Python\workspace_idea\GazeML_torch\src\models\gaze_modelbased.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   result = scipy.optimize.minimize(gaze_fit_loss_func, x0=np.array([theta, phi, delta, phase]),
# array([[0.2719683, 0.6788541]], dtype=float32)

# %%
label = gaze_label.cpu().detach().numpy()
label
# Out:
# array([[0.24832767, 0.67705154]], dtype=float32)

# %%
gaze_util.angular_error(predict, label)
# Out:
# array([1.35818017])
